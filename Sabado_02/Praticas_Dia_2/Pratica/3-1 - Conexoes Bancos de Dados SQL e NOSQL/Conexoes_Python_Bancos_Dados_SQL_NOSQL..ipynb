# %% [markdown]
# # Conexões com Bancos de Dados NoSQL e SQL em Python com Pandas e Jupyter Notebook

# %% [markdown]
# # MongoDB

# %%
# Instalador PyMongo
# !pip install pymongo
# Out:
# Collecting pymongo
#   Downloading https://files.pythonhosted.org/packages/89/52/829cb3b58047af08f4cf7905be3545b7718b96e9c83142072edb48ee5d05/pymongo-3.9.0-cp36-cp36m-win_amd64.whl (351kB)
# Installing collected packages: pymongo
# Successfully installed pymongo-3.9.0
# You are using pip version 18.1, however version 19.3.1 is available.
# You should consider upgrading via the 'python -m pip install --upgrade pip' command.

# %%
import pandas as pd

# Importando o Módulo PyMongo
import pymongo

# %%
# Criando a Conexão com o PyMongo

myclient = pymongo.MongoClient("mongodb://localhost:27017/")

# %%
# Ler e Armazenando o Banco/Documento e a Collection em Variáveis

mydb = myclient["local"]
mycol = mydb["startup_log"]

# %%
# retorna todos os registros da collection

for x in mycol.find():
    print(x)
# Out:
# {'_id': 'JPAD278145-1572610091103', 'hostname': 'JPAD278145', 'startTime': datetime.datetime(2019, 11, 1, 12, 8, 11), 'startTimeLocal': 'Fri Nov  1 09:08:11.103', 'cmdLine': {'config': 'C:\\Program Files\\MongoDB\\Server\\4.2\\bin\\mongod.cfg', 'net': {'bindIp': '127.0.0.1', 'port': 27017}, 'service': True, 'storage': {'dbPath': 'C:\\Program Files\\MongoDB\\Server\\4.2\\data', 'journal': {'enabled': True}}, 'systemLog': {'destination': 'file', 'logAppend': True, 'path': 'C:\\Program Files\\MongoDB\\Server\\4.2\\log\\mongod.log'}}, 'pid': 15264, 'buildinfo': {'version': '4.2.1', 'gitVersion': 'edf6d45851c0b9ee15548f0f847df141764a317e', 'targetMinOS': 'Windows 7/Windows Server 2008 R2', 'modules': [], 'allocator': 'tcmalloc', 'javascriptEngine': 'mozjs', 'sysInfo': 'deprecated', 'versionArray': [4, 2, 1, 0], 'openssl': {'running': 'Windows SChannel'}, 'buildEnvironment': {'distmod': '2012plus', 'distarch': 'x86_64', 'cc': 'cl: Microsoft (R) C/C++ Optimizing Compiler Version 19.16.27034 for x64', 'ccflags': '/nologo /EHsc /W3 /wd4068 /wd4244 /wd4267 /wd4290 /wd4351 /wd4355 /wd4373 /wd4800 /wd5041 /wd4291 /we4013 /we4099 /we4930 /WX /errorReport:none /MD /O2 /Oy- /bigobj /utf-8 /permissive- /Zc:__cplusplus /Zc:sizedDealloc /volatile:iso /diagnostics:caret /std:c++17 /Gw /Gy /Zc:inline', 'cxx': 'cl: Microsoft (R) C/C++ Optimizing Compiler Version 19.16.27034 for x64', 'cxxflags': '/TP', 'linkflags': '/nologo /DEBUG /INCREMENTAL:NO /LARGEADDRESSAWARE /OPT:REF', 'target_arch': 'x86_64', 'target_os': 'windows'}, 'bits': 64, 'debug': False, 'maxBsonObjectSize': 16777216, 'storageEngines': ['biggie', 'devnull', 'ephemeralForTest', 'wiredTiger']}}

# %%
# Retorna apenas as informações de Item e Quantidade

for x in mycol.find({}, {"_id":"JPAD278145-1572610091103", "hostname":"JPAD278145", "pid":15264}):
    print(x)
# Out:
# {'_id': 'JPAD278145-1572610091103', 'hostname': 'JPAD278145', 'pid': 15264}

# %%
# Retorna apenas o Item com pid 15264

myquery = {"pid":15264}

mydoc = mycol.find(myquery)

for x in mydoc:
    print(x)
# Out:
# {'_id': 'JPAD278145-1572610091103', 'hostname': 'JPAD278145', 'startTime': datetime.datetime(2019, 11, 1, 12, 8, 11), 'startTimeLocal': 'Fri Nov  1 09:08:11.103', 'cmdLine': {'config': 'C:\\Program Files\\MongoDB\\Server\\4.2\\bin\\mongod.cfg', 'net': {'bindIp': '127.0.0.1', 'port': 27017}, 'service': True, 'storage': {'dbPath': 'C:\\Program Files\\MongoDB\\Server\\4.2\\data', 'journal': {'enabled': True}}, 'systemLog': {'destination': 'file', 'logAppend': True, 'path': 'C:\\Program Files\\MongoDB\\Server\\4.2\\log\\mongod.log'}}, 'pid': 15264, 'buildinfo': {'version': '4.2.1', 'gitVersion': 'edf6d45851c0b9ee15548f0f847df141764a317e', 'targetMinOS': 'Windows 7/Windows Server 2008 R2', 'modules': [], 'allocator': 'tcmalloc', 'javascriptEngine': 'mozjs', 'sysInfo': 'deprecated', 'versionArray': [4, 2, 1, 0], 'openssl': {'running': 'Windows SChannel'}, 'buildEnvironment': {'distmod': '2012plus', 'distarch': 'x86_64', 'cc': 'cl: Microsoft (R) C/C++ Optimizing Compiler Version 19.16.27034 for x64', 'ccflags': '/nologo /EHsc /W3 /wd4068 /wd4244 /wd4267 /wd4290 /wd4351 /wd4355 /wd4373 /wd4800 /wd5041 /wd4291 /we4013 /we4099 /we4930 /WX /errorReport:none /MD /O2 /Oy- /bigobj /utf-8 /permissive- /Zc:__cplusplus /Zc:sizedDealloc /volatile:iso /diagnostics:caret /std:c++17 /Gw /Gy /Zc:inline', 'cxx': 'cl: Microsoft (R) C/C++ Optimizing Compiler Version 19.16.27034 for x64', 'cxxflags': '/TP', 'linkflags': '/nologo /DEBUG /INCREMENTAL:NO /LARGEADDRESSAWARE /OPT:REF', 'target_arch': 'x86_64', 'target_os': 'windows'}, 'bits': 64, 'debug': False, 'maxBsonObjectSize': 16777216, 'storageEngines': ['biggie', 'devnull', 'ephemeralForTest', 'wiredTiger']}}

# %%
df_mongo = pd.DataFrame(list(mycol.find()))

# %%
df_mongo.head()
# Out:
#                         _id  \
# 0  JPAD278145-1572610091103
#
#                                            buildinfo  \
# 0  {'version': '4.2.1', 'gitVersion': 'edf6d45851...
#
#                                              cmdLine    hostname    pid  \
# 0  {'config': 'C:\Program Files\MongoDB\Server\4....  JPAD278145  15264
#
#             startTime           startTimeLocal
# 0 2019-11-01 12:08:11  Fri Nov  1 09:08:11.103

# %% [markdown]
# # Mysql

# %%
# Instalando os Pacotes - Mysql
# !pip install pymysql
# Out:
# Collecting pymysql
#   Downloading https://files.pythonhosted.org/packages/ed/39/15045ae46f2a123019aa968dfcba0396c161c20f855f11dea6796bcaae95/PyMySQL-0.9.3-py2.py3-none-any.whl (47kB)
# Installing collected packages: pymysql
# Successfully installed pymysql-0.9.3
# You are using pip version 18.1, however version 19.3.1 is available.
# You should consider upgrading via the 'python -m pip install --upgrade pip' command.

# %%
# Importar Módulo pandas
import pandas as pd

# importar o módulo pymysql
import pymysql

# converter do pymysql para o Mysql
pymysql.install_as_MySQLdb()

#import mysql.connector
import MySQLdb

# %%
# Configurações paa MYSQL connection

# %%
db = MySQLdb.connect(
    host="localhost",
    user="root",
    password="72255560",
    database="dbclassificados"
)

# Cricar um objeto cursor. Isso permitirá que você execute todas as consultas necessárias
cur = db.cursor()

# Selecionar o que retornar todos os dados da tabela.
cur.execute("SELECT * FROM dbclassificados.tipoanuncio")


#Fechar a conexão.
db.close()
# Out:
# ---------------------------------------------------------------------------
# ConnectionRefusedError                    Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\pymysql\connections.py in connect(self, sock)
#     582                                 (self.host, self.port), self.connect_timeout,
# --> 583                                 **kwargs)
#     584                             break
#
# C:\ProgramData\Anaconda3\lib\socket.py in create_connection(address, timeout, source_address)
#     723     if err is not None:
# --> 724         raise err
#     725     else:
#
# C:\ProgramData\Anaconda3\lib\socket.py in create_connection(address, timeout, source_address)
#     712                 sock.bind(source_address)
# --> 713             sock.connect(sa)
#     714             # Break explicitly a reference cycle
#
# ConnectionRefusedError: [WinError 10061] Nenhuma conexão pôde ser feita porque a máquina de destino as recusou ativamente
#
# During handling of the above exception, another exception occurred:
#
# OperationalError                          Traceback (most recent call last)
# <ipython-input-29-fb10fe176336> in <module>
#       3     user="root",
#       4     password="72255560",
# ----> 5     database="dbclassificados"
#       6 )
#       7
#
# C:\ProgramData\Anaconda3\lib\site-packages\pymysql\__init__.py in Connect(*args, **kwargs)
#      92     """
#      93     from .connections import Connection
# ---> 94     return Connection(*args, **kwargs)
#      95
#      96 from . import connections as _orig_conn
#
# C:\ProgramData\Anaconda3\lib\site-packages\pymysql\connections.py in __init__(self, host, user, password, database, port, unix_socket, charset, sql_mode, read_default_file, conv, use_unicode, client_flag, cursorclass, init_command, connect_timeout, ssl, read_default_group, compress, named_pipe, autocommit, db, passwd, local_infile, max_allowed_packet, defer_connect, auth_plugin_map, read_timeout, write_timeout, bind_address, binary_prefix, program_name, server_public_key)
#     323             self._sock = None
#     324         else:
# --> 325             self.connect()
#     326
#     327     def _create_ssl_ctx(self, sslp):
#
# C:\ProgramData\Anaconda3\lib\site-packages\pymysql\connections.py in connect(self, sock)
#     628                 exc.traceback = traceback.format_exc()
#     629                 if DEBUG: print(exc.traceback)
# --> 630                 raise exc
#     631
#     632             # If e is neither DatabaseError or IOError, It's a bug.
#
# OperationalError: (2003, "Can't connect to MySQL server on 'localhost' ([WinError 10061] Nenhuma conexão pôde ser feita porque a máquina de destino as recusou ativamente)")

# %%
# Converter os dados para DATAFRAME
tb_cliente_mysql = pd.DataFrame(cur.fetchall())

# Visualizar os dados do DATAFRAME
tb_cliente_mysql.head()

#Adicionar o nome para as colunas

tb_cliente_mysql = tb_cliente_mysql.rename(columns={
                                                    0: 'codigo_tipoanuncio',
                                                    1: 'Descricao_Tipo'
                                                })


# Visualizar os dados com as colunas renomeadas

tb_cliente_mysql.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-30-d2d680859be5> in <module>
#       1 # Converter os dados para DATAFRAME
# ----> 2 tb_cliente_mysql = pd.DataFrame(cur.fetchall())
#       3
#       4 # Visualizar os dados do DATAFRAME
#
# NameError: name 'cur' is not defined

# %% [markdown]
# # PostgresSQL

# %%
# !pip install psycopg2
# Out:
# Collecting psycopg2
#   Downloading https://files.pythonhosted.org/packages/4a/d9/467aba4b587f97e4047b9ae8609f22dc01eea56eda92358089db89b729ef/psycopg2-2.8.4-cp36-cp36m-win_amd64.whl (1.1MB)
# Installing collected packages: psycopg2
# Successfully installed psycopg2-2.8.4
# You are using pip version 18.1, however version 19.3.1 is available.
# You should consider upgrading via the 'python -m pip install --upgrade pip' command.

# %%
import pandas as pd
import psycopg2

# %%
PGHOST = 'localhost'
PGDATABASE = 'postgres'
PGUSER = 'postgres'
PGPASSWORD = 'Ths122'
port = '5432'

# Configuração para conexão com o SGBD Postgresql

conn_string = "host="+ PGHOST \
            +" port="+ port \
            +" dbname="+ PGDATABASE \
            +" user="+ PGUSER \
            +" password="+ PGPASSWORD

conn = psycopg2.connect(conn_string)

# Selecionar os dados que estão retornando da tabela do banco..
tb_cliente_postgres = pd.read_sql_query(''' SELECT * FROM CLIENTE''', conn)

# Fecha a Conexão com o Banco..
conn.close()
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# <ipython-input-37-1a0b2d79e1cd> in <module>
#      13             +" password="+ PGPASSWORD
#      14
# ---> 15 conn = psycopg2.connect(conn_string)
#      16
#      17 # Selecionar os dados que estão retornando da tabela do banco..
#
# C:\ProgramData\Anaconda3\lib\site-packages\psycopg2\__init__.py in connect(dsn, connection_factory, cursor_factory, **kwargs)
#     124
#     125     dsn = _ext.make_dsn(dsn, **kwargs)
# --> 126     conn = _connect(dsn, connection_factory=connection_factory, **kwasync)
#     127     if cursor_factory is not None:
#     128         conn.cursor_factory = cursor_factory
#
# OperationalError: could not connect to server: Connection refused (0x0000274D/10061)
# 	Is the server running on host "localhost" (127.0.0.1) and accepting
# 	TCP/IP connections on port 5432?
# could not connect to server: Connection refused (0x0000274D/10061)
# 	Is the server running on host "localhost" (::1) and accepting
# 	TCP/IP connections on port 5432?

# %%
tb_cliente_postgres.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-38-bd1ea8258e63> in <module>
# ----> 1 tb_cliente_postgres.head()
#
# NameError: name 'tb_cliente_postgres' is not defined

# %%
# Fim..
